# %%
import pandas as pd 
import seaborn as sns
from sklearn import linear_model

# %%
df=pd.read_csv("C:\\Users\\Dell\\Documents\\vaishaliml\\house_prices_dataset.csv")
df
# Out:
#        area      price
# 0   2231.88  558852.17
# 1   2524.92  632260.29
# 2   1527.65  382994.25
# 3   1986.09  497607.86
# 4   2920.16  730870.84
# ..      ...        ...
# 95  2345.42  587342.25
# 96  1701.95  426321.81
# 97  2880.39  721159.46
# 98  2273.60  569238.36
# 99  2923.85  732054.33
#
# [100 rows x 2 columns]

# %%
sns.lmplot(x='area',y='price', data=df)

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['area']],df['price'])
# Out:
# LinearRegression()

# %%
reg.predict([[26]])
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([7503.75184626])

# %%
reg.predict([[60]])
# Out:
# C:\Users\Dell\AppData\Roaming\Python\Python312\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([16003.62467184])

# %%
reg.coef_
# Out:
# array([249.99625958])

# %%
reg.intercept_
# Out:
# 1003.8490972928703

# %%
#Linear equation => y=mx+c , price=m*x+c , price whose area is 26 
# y=m*x+c
# y =249.99625958*26+(1003.84909729)
# y=7503.75184637

# %%
# price whose area is 60
#y = m*x+c
#y = 249.99625958*60+(1003.84909729)
#y = 16003.62467206
